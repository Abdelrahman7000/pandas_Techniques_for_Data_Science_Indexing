# %%
import pandas as pd

# %%
# import the data
df=pd.read_csv('Big 5 European football leagues teams stats.csv')

# %%
df.head()
# Out:
#       competition     season  rank            squad  games  wins  draws  \
# 0  Premier League  2010-2011     1   Manchester Utd     38    23     11
# 1  Premier League  2010-2011     2          Chelsea     38    21      8
# 2  Premier League  2010-2011     3  Manchester City     38    21      8
# 3  Premier League  2010-2011     4          Arsenal     38    19     11
# 4  Premier League  2010-2011     5        Tottenham     38    16     14
#
#    losses  goals_for  goals_against  ...  cards_red  shots_on_target_against  \
# 0       4         78             37  ...        3.0                      139
# 1       9         69             33  ...        1.0                      148
# 2       9         60             33  ...        5.0                      153
# 3       8         72             43  ...        6.0                      150
# 4       8         55             46  ...        2.0                      183
#
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1078, step=1)

# %%
# Select the first six rows using square brackets
df[:6]
# Out:
#       competition     season  rank            squad  games  wins  draws  \
# 0  Premier League  2010-2011     1   Manchester Utd     38    23     11
# 1  Premier League  2010-2011     2          Chelsea     38    21      8
# 2  Premier League  2010-2011     3  Manchester City     38    21      8
# 3  Premier League  2010-2011     4          Arsenal     38    19     11
# 4  Premier League  2010-2011     5        Tottenham     38    16     14
# 5  Premier League  2010-2011     6        Liverpool     38    17      7
#
#    losses  goals_for  goals_against  ...  cards_red  shots_on_target_against  \
# 0       4         78             37  ...        3.0                      139
# 1       9         69             33  ...        1.0                      148
# 2       9         60             33  ...        5.0                      153
# 3       8         72             43  ...        6.0                      150
# 4       8         55             46  ...        2.0                      183
# ...

# %%
df.iloc[7:13,:]
# Out:
#        competition     season  rank          squad  games  wins  draws  \
# 7   Premier League  2010-2011     8         Fulham     38    11     16
# 8   Premier League  2010-2011     9    Aston Villa     38    12     12
# 9   Premier League  2010-2011    10     Sunderland     38    12     11
# 10  Premier League  2010-2011    11      West Brom     38    12     11
# 11  Premier League  2010-2011    12  Newcastle Utd     38    11     13
# 12  Premier League  2010-2011    13     Stoke City     38    13      7
#
#     losses  goals_for  goals_against  ...  cards_red  shots_on_target_against  \
# 7       11         49             43  ...        1.0                      171
# 8       14         48             59  ...        2.0                      189
# 9       15         45             56  ...        5.0                      206
# 10      15         56             71  ...        7.0                      182
# 11      14         56             57  ...        2.0                      161
# ...

# %%
df.loc[[3,33,43,66,86,90],'competition':'goals_against']
# Out:
#        competition     season  rank           squad  games  wins  draws  \
# 3   Premier League  2010-2011     4         Arsenal     38    19     11
# 33  Premier League  2011-2012    14      Stoke City     38    11     12
# 43  Premier League  2012-2013     4         Arsenal     38    21     10
# 66  Premier League  2013-2014     7  Manchester Utd     38    19      7
# 86  Premier League  2014-2015     7     Southampton     38    18      6
# 90  Premier League  2014-2015    11         Everton     38    12     11
#
#     losses  goals_for  goals_against
# 3        8         72             43
# 33      15         36             53
# 43       7         72             37
# 66      12         64             43
# 86      14         54             33
# 90      15         48             50

# %%
df.set_index('rank',inplace=True)

# %%
df.head()
# Out:
#          competition     season            squad  games  wins  draws  losses  \
# rank
# 1     Premier League  2010-2011   Manchester Utd     38    23     11       4
# 2     Premier League  2010-2011          Chelsea     38    21      8       9
# 3     Premier League  2010-2011  Manchester City     38    21      8       9
# 4     Premier League  2010-2011          Arsenal     38    19     11       8
# 5     Premier League  2010-2011        Tottenham     38    16     14       8
#
#       goals_for  goals_against  goal_diff  ...  cards_red  \
# rank                                       ...
# 1            78             37         41  ...        3.0
# 2            69             33         36  ...        1.0
# 3            60             33         27  ...        5.0
# 4            72             43         29  ...        6.0
# 5            55             46          9  ...        2.0
#
#      shots_on_target_against  saves  clean_sheets  shots_on_target  \
# rank
# ...

# %%
df.loc[10,:]
# Out:
#              competition     season           squad  games  wins  draws  \
# rank
# 10        Premier League  2010-2011      Sunderland     38    12     11
# 10        Premier League  2011-2012       West Brom     38    13      8
# 10        Premier League  2012-2013        West Ham     38    12     10
# 10        Premier League  2013-2014   Newcastle Utd     38    15      4
# 10        Premier League  2014-2015  Crystal Palace     38    13      9
# 10        Premier League  2015-2016         Chelsea     38    12     14
# 10        Premier League  2016-2017       West Brom     38    12      9
# 10        Premier League  2017-2018   Newcastle Utd     38    12      8
# 10        Premier League  2018-2019        West Ham     38    15      7
# 10        Premier League  2019-2020         Burnley     38    15      9
# 10        Premier League  2020-2021         Everton     38    17      8
# 10               Ligue 1  2010-2011   Saint-Étienne     38    12     13
# ...

# %%
df.iloc[10:17,0:6]
# Out:
#          competition     season           squad  games  wins  draws
# rank
# 11    Premier League  2010-2011       West Brom     38    12     11
# 12    Premier League  2010-2011   Newcastle Utd     38    11     13
# 13    Premier League  2010-2011      Stoke City     38    13      7
# 14    Premier League  2010-2011          Bolton     38    12     10
# 15    Premier League  2010-2011       Blackburn     38    11     10
# 16    Premier League  2010-2011  Wigan Athletic     38     9     15
# 17    Premier League  2010-2011          Wolves     38    11      7

# %%
df.reset_index(inplace=True)

# %%
df.set_index(['rank','squad'],inplace=True)

# %%
df.head()
# Out:
#                          competition     season  games  wins  draws  losses  \
# rank squad
# 1    Manchester Utd   Premier League  2010-2011     38    23     11       4
# 2    Chelsea          Premier League  2010-2011     38    21      8       9
# 3    Manchester City  Premier League  2010-2011     38    21      8       9
# 4    Arsenal          Premier League  2010-2011     38    19     11       8
# 5    Tottenham        Premier League  2010-2011     38    16     14       8
#
#                       goals_for  goals_against  goal_diff  points  ...  \
# rank squad                                                         ...
# 1    Manchester Utd          78             37         41      80  ...
# 2    Chelsea                 69             33         36      71  ...
# 3    Manchester City         60             33         27      71  ...
# 4    Arsenal                 72             43         29      68  ...
# 5    Tottenham               55             46          9      62  ...
# ...

# %%
df.index
# Out:
# MultiIndex([( 1,  'Manchester Utd'),
#             ( 2,         'Chelsea'),
#             ( 3, 'Manchester City'),
#             ( 4,         'Arsenal'),
#             ( 5,       'Tottenham'),
#             ( 6,       'Liverpool'),
#             ( 7,         'Everton'),
#             ( 8,          'Fulham'),
#             ( 9,     'Aston Villa'),
#             (10,      'Sunderland'),
#             ...
#             (11,         'Osasuna'),
#             (12,           'Cádiz'),
#             (13,        'Valencia'),
#             (14,         'Levante'),
#             (15,          'Getafe'),
#             (16,          'Alavés'),
#             (17,           'Elche'),
#             (18,          'Huesca'),
#             (19,      'Valladolid'),
#             (20,           'Eibar')],
#            names=['rank', 'squad'], length=1078)

# %%
df.sort_index(inplace=True)

# %%
df.head()
# Out:
#                      competition     season  games  wins  draws  losses  \
# rank squad
# 1    Atlético Madrid     La Liga  2013-2014     38    28      6       4
#      Atlético Madrid     La Liga  2020-2021     38    26      8       4
#      Barcelona           La Liga  2010-2011     38    30      6       2
#      Barcelona           La Liga  2012-2013     38    32      4       2
#      Barcelona           La Liga  2014-2015     38    30      4       4
#
#                       goals_for  goals_against  goal_diff  points  ...  \
# rank squad                                                         ...
# 1    Atlético Madrid         77             26         51      90  ...
#      Atlético Madrid         67             25         42      86  ...
#      Barcelona               95             21         74      96  ...
#      Barcelona              115             40         75     100  ...
#      Barcelona              110             21         89      94  ...
#
# ...

# %%
df.loc[(6,'Liverpool')]
# Out:
#                    competition     season  games  wins  draws  losses  \
# rank squad
# 6    Liverpool  Premier League  2010-2011     38    17      7      14
#      Liverpool  Premier League  2014-2015     38    18      8      12
#
#                 goals_for  goals_against  goal_diff  points  ... cards_red  \
# rank squad                                                   ...
# 6    Liverpool         59             44         15      58  ...       2.0
#      Liverpool         52             48          4      62  ...       0.0
#
#                 shots_on_target_against  saves  clean_sheets  shots_on_target  \
# rank squad
# 6    Liverpool                      149    105            14              204
#      Liverpool                      139     91            14              193
#
#                 games_starts  games_complete  games_subs  unused_subs  \
# rank squad
# 6    Liverpool           418             NaN          93          NaN
# ...

# %%
s=[(1,'Barcelona'),(4,'Arsenal')]
df.loc[s]
# Out:
#                    competition     season  games  wins  draws  losses  \
# rank squad
# 1    Barcelona         La Liga  2010-2011     38    30      6       2
#      Barcelona         La Liga  2012-2013     38    32      4       2
#      Barcelona         La Liga  2014-2015     38    30      4       4
#      Barcelona         La Liga  2015-2016     38    29      4       5
#      Barcelona         La Liga  2017-2018     38    28      9       1
#      Barcelona         La Liga  2018-2019     38    26      9       3
# 4    Arsenal    Premier League  2010-2011     38    19     11       8
#      Arsenal    Premier League  2012-2013     38    21     10       7
#      Arsenal    Premier League  2013-2014     38    24      7       7
#
#                 goals_for  goals_against  goal_diff  points  ... cards_red  \
# rank squad                                                   ...
# 1    Barcelona         95             21         74      96  ...       2.0
# ...

# %%
# sort the inner index which is sqad
df.sort_index(level="squad")
# Out:
#                   competition     season  games  wins  draws  losses  \
# rank squad
# 16   Ajaccio          Ligue 1  2011-2012     38     9     14      15
# 17   Ajaccio          Ligue 1  2012-2013     38     9     15      14
# 20   Ajaccio          Ligue 1  2013-2014     38     4     11      23
# 9    Alavés           La Liga  2016-2017     38    14     13      11
# 11   Alavés           La Liga  2018-2019     38    13     11      14
# ...                       ...        ...    ...   ...    ...     ...
# 17   Wolves    Premier League  2010-2011     38    11      7      20
# 20   Wolves    Premier League  2011-2012     38     5     10      23
# 13   Zaragoza         La Liga  2010-2011     38    12      9      17
# 16   Zaragoza         La Liga  2011-2012     38    12      7      19
# 20   Zaragoza         La Liga  2012-2013     38     9      7      22
#
#                goals_for  goals_against  goal_diff  points  ... cards_red  \
# ...
